# %%
#load csv with numpy
import csv
import numpy
import pandas as pd
filename=open('pima-indians-diabetes.csv')

# %%
reader=csv.reader(filename,delimiter=',',quoting=csv.QUOTE_NONE)
x=list(reader)
data=numpy.array(x).astype('float')
print(data.shape)
# Out:
# (768, 9)

# %%
print(data)
# Out:
# [[  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  [  8.    183.     64.    ...   0.672  32.      1.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]

# %%
#load csv using pandas
import pandas
filename=open('pima-indians-diabetes.csv')
names=['preg','plas','pres','skin','test','mass','pedi','age','class']
data=pandas.read_csv(filename,names=names)
print(data)
print(data.shape)
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]
# (768, 9)

# %%
#load and show an image with pillow
from PIL import Image
#load the image
image=Image.open('kitten.jpg')

# %%
#summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
#show the image
image.show()
# Out:
# WEBP
# RGB
# (1600, 900)

# %%
#load and display an image with matplotlib
from matplotlib import image
from matplotlib import pyplot
#load image as pixel array
data=image.imread('kitten.jpg')
#summarize shape of the pixel array
print(data.dtype)
print(data.shape)
#display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (900, 1600, 3)

# %%
#load image and convert to and from numpy array
from PIL import Image
from numpy import asarray
#load the image
image=Image.open('kitten.jpg')
#convert image to numpy array
data=asarray(image)
print(data)
#summarize shape
print(data.shape)
#create pillow iimage
image2=Image.fromarray(data)
#summarize image details
print(image2.mode)
print(image2.size)
image2.show()
# Out:
# [[[ 98 156  64]
#   [ 98 156  64]
#   [ 99 157  65]
#   ...
#   [ 31  80  46]
#   [ 31  80  46]
#   [ 31  80  46]]
#
#  [[ 98 156  64]
#   [ 98 156  64]
#   [ 99 157  65]
#   ...
#   [ 31  80  46]
#   [ 31  80  46]
#   [ 31  80  46]]
#
#  [[ 99 157  65]
#   [ 99 157  65]
#   [100 158  66]
#   ...
#   [ 31  80  46]
#   [ 31  80  46]
#   [ 31  80  46]]
#
#  ...
#
#  [[108 118  41]
#   [108 118  41]
#   [109 119  43]
#   ...
#   [ 51  83  42]
#   [ 52  84  44]
#   [ 52  84  44]]
#
#  [[106 116  42]
#   [106 116  42]
#   [109 118  45]
#   ...
#   [ 51  83  42]
#   [ 52  84  44]
#   [ 52  84  44]]
#
#  [[105 115  41]
#   [105 115  41]
#   [108 117  43]
#   ...
#   [ 51  83  42]
#   [ 52  84  44]
#   [ 52  84  44]]]
# (900, 1600, 3)
# RGB
# (1600, 900)

# %%
#example of saving a grayscale version of a loaded image
from PIL import Image
#load the image
image=Image.open('kitten.jpg')
#convert the image to grayscale
gs_image=image.convert(mode='L')
#save in jpeg format
gs_image.save('kitten1.jpg')
#load the image again and show it
image2=Image.open('kitten1.jpg')
#show the image
image2.show()
